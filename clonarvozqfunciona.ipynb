# %%
# 1. Clonar o repositório
# !git clone https://github.com/RVC-Boss/GPT-SoVITS.git

# 2. Entrar na pasta do projeto
# %cd GPT-SoVITS

# 3. Instalação de dependências do sistema
# !apt-get update && apt-get install -y ffmpeg

# 4. Instalação das dependências do Python
# !pip install -r requirements.txt
# Out:
# fatal: destination path 'GPT-SoVITS' already exists and is not an empty directory.
# /content/GPT-SoVITS
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Ign:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Ign:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Ign:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Ign:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# ...

# %% [markdown]
# ### Ajustando dependências e reinstalando
#
# Vamos remover o `opencc` do arquivo de requisitos para evitar o erro de compilação e tentar instalar o restante das bibliotecas.

# %%
# Remove opencc do requirements.txt para evitar erro de compilação
# !sed -i '/opencc/d' requirements.txt

# Tenta instalar novamente as dependências
# !pip install -r requirements.txt
# Out:
# Ignoring onnxruntime: markers 'platform_machine == "aarch64" or platform_machine == "arm64"' don't match your environment
# ...

# %%
# !pip install opencc-python-reimplemented

# %% [markdown]
# ### Preparação do Dataset
# Criando a pasta local para onde você deve subir seus arquivos de áudio.

# %%
import os

# Define o nome da pasta para seus áudios
dataset_path = "/content/GPT-SoVITS/dados_treinamento"

os.makedirs(dataset_path, exist_ok=True)

print(f"Pasta criada em: {dataset_path}")
print("Você já pode subir seus arquivos de áudio para esta pasta usando o ícone de pasta na lateral esquerda.")
# Out:
# Pasta criada em: /content/GPT-SoVITS/dados_treinamento
# Você já pode subir seus arquivos de áudio para esta pasta usando o ícone de pasta na lateral esquerda.

# %% [markdown]
# ### Iniciando a WebUI do GPT-SoVITS
#
# Execute a célula abaixo para abrir a interface de treinamento. Clique no link **público** que aparecerá (terminando em `.gradio.live`).

# %%
# Entra na pasta do projeto caso não esteja nela
# %cd /content/GPT-SoVITS

# Define a linguagem para português na interface (se disponível) ou inglês por padrão
os.environ["lang"] = "en"

# Comando para iniciar a interface com link público
# !python webui.py
# Out:
# /content/GPT-SoVITS
# ...
#     GPT_SoVITS/pretrained_models/v2Pro/s2Gv2Pro.pth
#     GPT_SoVITS/pretrained_models/v2Pro/s2Dv2Pro.pth
#     GPT_SoVITS/pretrained_models/s1v3.ckpt
#     GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large
#     GPT_SoVITS/pretrained_models/chinese-hubert-base
# Traceback (most recent call last):
#   File "/content/GPT-SoVITS/GPT_SoVITS/download.py", line 6, in <module>
#     from text.g2pw import G2PWPinyin
#   File "/content/GPT-SoVITS/GPT_SoVITS/text/g2pw/__init__.py", line 1, in <module>
#     from text.g2pw.g2pw import *
#   File "/content/GPT-SoVITS/GPT_SoVITS/text/g2pw/g2pw.py", line 11, in <module>
#     from .onnx_api import G2PWOnnxConverter
#   File "/content/GPT-SoVITS/GPT_SoVITS/text/g2pw/onnx_api.py", line 13, in <module>
#     from opencc import OpenCC
# ModuleNotFoundError: No module named 'opencc'
# Running on local URL:  http://0.0.0.0:9874
#
# To create a public link, set `share=True` in `launch()`.
# ...

# %%
# Modificando o comando para forçar o link público do Gradio
# %cd /content/GPT-SoVITS
# !python webui.py --share
# Out:
# /content/GPT-SoVITS
# ...
#     GPT_SoVITS/pretrained_models/v2Pro/s2Gv2Pro.pth
#     GPT_SoVITS/pretrained_models/v2Pro/s2Dv2Pro.pth
#     GPT_SoVITS/pretrained_models/s1v3.ckpt
#     GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large
#     GPT_SoVITS/pretrained_models/chinese-hubert-base
# ...
# Extracting g2pw model...
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/hub.py", line 424, in cached_files
#     hf_hub_download(
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 106, in _inner_fn
#     validate_repo_id(arg_value)
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 154, in validate_repo_id
#     raise HFValidationError(
# huggingface_hub.errors.HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large'. Use `repo_type` argument if needed.
#
# ...

# %% [markdown]
# ### Baixando modelos base essenciais
# Para que a interface abra, precisamos de alguns modelos pequenos de processamento que o sistema exige na inicialização.

# %%
# Cria as pastas necessárias para os modelos base
# !mkdir -p GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large
# !mkdir -p GPT_SoVITS/pretrained_models/chinese-hubert-base

# Baixa os arquivos de configuração e pesos mínimos (Hubert e Roberta)
# !wget https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/chinese-roberta-wwm-ext-large/config.json -O GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large/config.json
# !wget https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/chinese-roberta-wwm-ext-large/pytorch_model.bin -O GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large/pytorch_model.bin
# !wget https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/chinese-roberta-wwm-ext-large/tokenizer.json -O GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large/tokenizer.json

# !wget https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/chinese-hubert-base/config.json -O GPT_SoVITS/pretrained_models/chinese-hubert-base/config.json
# !wget https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/chinese-hubert-base/pytorch_model.bin -O GPT_SoVITS/pretrained_models/chinese-hubert-base/pytorch_model.bin

print("Modelos base baixados. Tente rodar a célula da WebUI novamente!")
# Out:
# --2026-05-03 22:06:22--  https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/chinese-roberta-wwm-ext-large/config.json
# Resolving huggingface.co (huggingface.co)... 18.164.174.17, 18.164.174.55, 18.164.174.118, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.17|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: /api/resolve-cache/models/lj1995/GPT-SoVITS/336b2ec4e8d4ac74740798dd40af44e74659ecaf/chinese-roberta-wwm-ext-large%2Fconfig.json?%2Flj1995%2FGPT-SoVITS%2Fresolve%2Fmain%2Fchinese-roberta-wwm-ext-large%2Fconfig.json=&etag=%223ae58d7f0734373bb28d3b6b9d6858b34f600b4a%22 [following]
# --2026-05-03 22:06:22--  https://huggingface.co/api/resolve-cache/models/lj1995/GPT-SoVITS/336b2ec4e8d4ac74740798dd40af44e74659ecaf/chinese-roberta-wwm-ext-large%2Fconfig.json?%2Flj1995%2FGPT-SoVITS%2Fresolve%2Fmain%2Fchinese-roberta-wwm-ext-large%2Fconfig.json=&etag=%223ae58d7f0734373bb28d3b6b9d6858b34f600b4a%22
# ...

# %%
# Inicia a WebUI com link público
# %cd /content/GPT-SoVITS
# !python webui.py --share
# Out:
# /content/GPT-SoVITS
# ...
#     GPT_SoVITS/pretrained_models/v2Pro/s2Gv2Pro.pth
#     GPT_SoVITS/pretrained_models/v2Pro/s2Dv2Pro.pth
#     GPT_SoVITS/pretrained_models/s1v3.ckpt
# Running on local URL:  http://0.0.0.0:9874
#
# To create a public link, set `share=True` in `launch()`.
# Keyboard interruption in main thread... closing server.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 2709, in block_thread
#     time.sleep(0.1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/GPT-SoVITS/webui.py", line 1975, in <module>
#     app.queue().launch(  # concurrency_count=511, max_size=1022
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 2614, in launch
#     self.block_thread()
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 2711, in block_thread
# ...

# %%
# Força o parâmetro share=True no arquivo webui.py para garantir o link público
# !sed -i 's/share=is_share/share=True/g' /content/GPT-SoVITS/webui.py
# !sed -i 's/inbrowser=True/inbrowser=False/g' /content/GPT-SoVITS/webui.py

print('Configuração de link público aplicada! Agora execute a célula abaixo para abrir a interface.')
# Out:
# Configuração de link público aplicada! Agora execute a célula abaixo para abrir a interface.

# %%
# Inicia a WebUI novamente
# %cd /content/GPT-SoVITS
# !python webui.py
# Out:
# /content/GPT-SoVITS
# ...
#     GPT_SoVITS/pretrained_models/v2Pro/s2Gv2Pro.pth
#     GPT_SoVITS/pretrained_models/v2Pro/s2Dv2Pro.pth
#     GPT_SoVITS/pretrained_models/s1v3.ckpt
# Running on local URL:  http://0.0.0.0:9874
# Running on public URL: https://654ead88f0372ee280.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
